# %%
import pandas as pd

# %%
data = pd.read_csv('insurance.csv')

# %%
df = pd.DataFrame(data)

# %%
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['sex'] = df['sex'].map({'female' : 0, 'male' : 1})

# %%
df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df['smoker'] = df['smoker'].map({'no' : 0, 'yes' : 1})

# %%
df.drop('region', axis=1, inplace=True)

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker      charges
# 0   19    0  27.900         0       1  16884.92400
# 1   18    1  33.770         1       0   1725.55230
# 2   28    1  33.000         3       0   4449.46200
# 3   33    1  22.705         0       0  21984.47061
# 4   32    1  28.880         0       0   3866.85520

# %%
x = df.drop('charges', axis=1)
y = df['charges']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split    
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
rfr= RandomForestRegressor()
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rfr.score(x_test, y_test)
# Out:
# 0.8731507986922113

# %%
rfr.score(x_train, y_train)
# Out:
# 0.9730106917114767

# %%
import joblib
joblib.dump(rfr, 'insurance_model.joblib')
# Out:
# ['insurance_model.joblib']

# %%
model = joblib.load('insurance_model.joblib')

# %%
model.predict(x_test)
# Out:
# array([ 8941.3024342, 10313.6116778, 12231.0855059, 44383.2635249,
#         6251.3708527, 11100.4516387, 38386.3661541,  2541.7707104,
#        11499.227911 , 10897.8608609, 14506.6038844, 23996.2522018,
#        44587.1749426, 15528.4566029,  6191.2810131,  9937.1098505,
#         7927.3471133, 39547.6102779,  7028.8253546,  6021.261034 ,
#         4070.8067334, 20278.70623  , 10236.9221681, 21751.6415512,
#        39558.2400023, 16167.6041693, 42599.2335544, 45584.5629335,
#         9986.1124732, 12384.0285328,  4657.7232166,  9705.0687853,
#         4221.5766813, 14369.5002092, 47523.0355984,  9979.8034684,
#        15481.6584762,  5046.964189 , 23462.4161588,  8493.9418252,
#         1946.928855 , 20322.7357823, 41414.1655755,  9389.189849 ,
#         9387.8736521,  4120.9873806,  1757.0255185,  8343.906435 ,
#         6362.4808408,  9237.0660258,  5744.4721883,  6797.9819712,
#        23380.8689784,  5947.7701947,  8123.4622487, 11383.2483255,
#        11902.5904887,  5956.4806974, 42766.4893533,  7387.8110098,
#        10896.7604812,  5352.6654177, 15708.4204341,  1670.1922685,
#        14498.1218468, 12192.9760599,  6530.980792 , 23750.1026751,
#        17045.550155 , 17440.1946765, 12076.4463544, 14159.713227 ,
#         7168.3850699,  2569.7339995, 11066.0418508,  3524.9693706,
#        14231.7010904,  5449.5422457, 10882.3761261, 12905.8877902,
#         8136.9017229, 16817.4720141, 14426.9779446, 14236.9097767,
#        28819.0017515, 14586.0323003,  3352.834872 ,  3996.9438315,
#         3737.3313365,  3616.1195914, 15852.0022284, 17977.1019525,
#        10062.4709751,  8964.2680313,  2376.158318 , 43571.0076125,
#        11900.5548375,  8906.6422389,  3959.9177448,  8914.5438584,
#        14065.538311 , 17310.2143191, 24733.4875211, 19721.4625078,
#        40064.6951669,  1558.1177985, 40485.9491095, 18749.9731636,
#        12433.1110701,  5052.0010828,  6693.3881364, 13184.3759287,
